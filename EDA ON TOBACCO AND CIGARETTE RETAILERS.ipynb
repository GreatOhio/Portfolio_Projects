# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = (12,8)

# %%
df = pd.read_csv("All_Cigarette_and_Tobacco_Retailers.csv")
df.head(10)
# Out:
#    Taxpayer Id            Taxpayer Name              Location Name  \
# 0  10106415143     SHELLIE CURTIS, INC.  MIGALITOS SUPERMERCADO #3
# 1  12011638892    BAYWAY BUSINESS, INC.              R D FOOD MART
# 2  10106415143     SHELLIE CURTIS, INC.  MIGALITOS SUPERMERCADO #4
# 3  12010833395                  JTP LLC                   PORTER'S
# 4  10106576951             SOFIAN, INC.              SDS FOOD MART
# 5  12036882780   AUSTIN PETROLEUM, INC.                  BREAKTIME
# 6  10106931867       STARCO OIL CO INC.               TOBACCO STOP
# 7  10106931867       STARCO OIL CO INC.               TOBACCO STOP
# 8  10105547839  S S S ENTERPRISES, INC.             ON THE GO MART
# 9  10106136012    YAM ENTERPRISES, INC.             STOP N SHOP #2
#
#                     Address        City State    Zip   Zip+4     County  \
# 0    3939 S POLK ST STE 323      DALLAS    TX  75224  4423.0     DALLAS
# 1            6114 DECKER DR     BAYTOWN    TX  77520  1444.0     HARRIS
# 2  333 S SAINT AUGUSTINE DR      DALLAS    TX  75217  7488.0     DALLAS
# 3            703 E FRONT ST     MIDLAND    TX  79701  4834.0    MIDLAND
# 4  4924 WHITE SETTLEMENT RD  FORT WORTH    TX  76114  3919.0    TARRANT
# 5            3502 MANGUM RD     HOUSTON    TX  77092  7418.0     HARRIS
# 6       117 INTERSTATE 45 S  HUNTSVILLE    TX  77340  4243.0     WALKER
# 7       117 INTERSTATE 45 S  HUNTSVILLE    TX  77340  4243.0     WALKER
# 8            8901 HOWARD DR     HOUSTON    TX  77017  5430.0     HARRIS
# 9             1301 AVENUE I   ROSENBERG    TX  77471  3205.0  FORT BEND
#
#    Location Number       Permit Type  Permit Number Permit Status  \
# 0                5  CIG/TOB RETAILER     22011140.0        ACTIVE
# 1                1    E-CIG RETAILER     22000106.0        ACTIVE
# 2                6  CIG/TOB RETAILER     22011243.0        ACTIVE
# 3                9  CIG/TOB RETAILER     19000685.0        ACTIVE
# 4                1  CIG/TOB RETAILER      3004834.0        ACTIVE
# 5                5    E-CIG RETAILER     21010591.0      INACTIVE
# 6                4  CIG/TOB RETAILER     12003229.0        ACTIVE
# 7                4    E-CIG RETAILER     21013363.0        ACTIVE
# 8                2    E-CIG RETAILER     22002640.0        ACTIVE
# 9                2  CIG/TOB RETAILER      2003938.0        ACTIVE
#
#   Permit Begin Date Permit End Date
# 0        08/26/2022             NaN
# 1        01/01/2022             NaN
# 2        08/26/2022             NaN
# 3        03/18/2019             NaN
# 4        01/01/2004             NaN
# 5        01/01/2022      11/02/2022
# 6        05/21/2012             NaN
# 7        01/01/2022             NaN
# 8        02/05/2022             NaN
# 9        07/01/2002             NaN

# %%
#Checking for data types for each column

df.dtypes
# Out:
# Taxpayer Id            int64
# Taxpayer Name         object
# Location Name         object
# Address               object
# City                  object
# State                 object
# Zip                    int64
# Zip+4                float64
# County                object
# Location Number        int64
# Permit Type           object
# Permit Number        float64
# Permit Status         object
# Permit Begin Date     object
# Permit End Date       object
# dtype: object

# %%
# Checking for row and column size 

df.shape
# Out:
# (73601, 15)

# %%
# Checking for columns with null value 

df.isnull().sum()
# Out:
# Taxpayer Id              0
# Taxpayer Name            0
# Location Name            1
# Address                  0
# City                     0
# State                    0
# Zip                      0
# Zip+4                 7932
# County                  37
# Location Number          0
# Permit Type              0
# Permit Number          802
# Permit Status            0
# Permit Begin Date        0
# Permit End Date      59506
# dtype: int64

# %%
# observing the row information with null value in the location name so as to deduce name from other rows with similar properties

df.loc[df["Location Name"].isnull()].index
# Out:
# Int64Index([66527], dtype='int64')

# %%
df.iloc[66527]
# Out:
# Taxpayer Id               32083270028
# Taxpayer Name        ADRIENNE VASQUEZ
# Location Name                     NaN
# Address                 2810 BOONE DR
# City                       LAGO VISTA
# State                              TX
# Zip                             78645
# Zip+4                            7201
# County                         TRAVIS
# Location Number                     1
# Permit Type            E-CIG RETAILER
# Permit Number                     NaN
# Permit Status                INACTIVE
# Permit Begin Date          08/31/2022
# Permit End Date                   NaN
# Name: 66527, dtype: object

# %%
# Checking for rows with city LAGO VISTA and County TRAVIS in order to deduce location name with null value 

(df[(df['County']=="TRAVIS") & (df['City']== "LAGO VISTA")])
# Out:
#        Taxpayer Id                         Taxpayer Name  \
# 5886   16111931362             DOLGENCORP OF TEXAS, INC.
# 10521  17422287924                   CEFCO A PARTNERSHIP
# 10590  17422287924                   CEFCO A PARTNERSHIP
# 12503  17429117819                HILLSIDE GROCERY, INC.
# 12504  17429117819                HILLSIDE GROCERY, INC.
# 16888  17515744815                    PAY AND SAVE, INC.
# 18388  17526928399             BROOKSHIRE BROTHERS, INC.
# 19058  17532312828  POINT VENTURE RESTAURANT GROUP, INC.
# 28305  32040270913           LAGO NAYAAB ENTERPRISES INC
# 28306  32040270913           LAGO NAYAAB ENTERPRISES INC
# 31949  32047784528                     JN ENTERPRISE INC
# 31950  32047784528                     JN ENTERPRISE INC
# 32963  32049875993                      LAGO SHAYAN, INC
# 32964  32049875993                      LAGO SHAYAN, INC
# 39296  32058283758                 HASHEM ENTERPRISE LLC
# 48915  32067653298                    LOHMAN XPRESS, INC
# 48916  32067653298                    LOHMAN XPRESS, INC
# 48917  32067653355                     KADEN XPRESS, INC
# 48918  32067653355                     KADEN XPRESS, INC
# 51365  32069837808              LOHMAN FORD BUSINESS LLC
# 66527  32083270028                      ADRIENNE VASQUEZ
#
#                   Location Name                       Address        City  \
# 5886     DOLLAR GENERAL # 10554                8017 BRONCO LN  LAGO VISTA
# 10521                 CEFCO #36                 20520 FM 1431  LAGO VISTA
# 10590                 CEFCO #36                 20520 FM 1431  LAGO VISTA
# 12503          HILLSIDE GROCERY          7501 LOHMANS FORD RD  LAGO VISTA
# 12504          HILLSIDE GROCERY          7501 LOHMANS FORD RD  LAGO VISTA
# 16888               LOWE'S #161          7708 LOHMANS FORD RD  LAGO VISTA
# 18388  BROOKSHIRE BROTHERS #117                8087 BRONCO LN  LAGO VISTA
# 19058            THE GNARLY GAR            18200 LAKEPOINT CV  LAGO VISTA
# 28305               SLR GROCERY          6004 LOHMANS FORD RD  LAGO VISTA
# 28306               SLR GROCERY          6004 LOHMANS FORD RD  LAGO VISTA
# 31949           NEW LAGO LIQUOR  6015 LOHMANS FORD RD STE 104  LAGO VISTA
# 31950           NEW LAGO LIQUOR  6015 LOHMANS FORD RD STE 104  LAGO VISTA
# 32963                    OSKI'S         20602 FM 1431 STE 100  LAGO VISTA
# 32964                    OSKI'S         20602 FM 1431 STE 100  LAGO VISTA
# 39296   LAKESIDE WINE & SPIRITS  7708 LOHMANS FORD RD STE 101  LAGO VISTA
# 48915            BOGGY'S LIQUOR   4712 LOHMAN FORD RD STE 200  LAGO VISTA
# 48916            BOGGY'S LIQUOR   4712 LOHMAN FORD RD STE 200  LAGO VISTA
# 48917         LAGO VISTA XPRESS   4712 LOHMAN FORD RD STE 100  LAGO VISTA
# 48918         LAGO VISTA XPRESS   4712 LOHMAN FORD RD STE 100  LAGO VISTA
# 51365              FUEL WISE #4          7600 LOHMANS FORD RD  LAGO VISTA
# 66527                       NaN                 2810 BOONE DR  LAGO VISTA
#
#       State    Zip   Zip+4  County  Location Number       Permit Type  \
# 5886     TX  78645  4528.0  TRAVIS             1223  CIG/TOB RETAILER
# 10521    TX  78645  4458.0  TRAVIS               97  CIG/TOB RETAILER
# 10590    TX  78645  4458.0  TRAVIS               97    E-CIG RETAILER
# 12503    TX  78645  4741.0  TRAVIS                1  CIG/TOB RETAILER
# 12504    TX  78645  4741.0  TRAVIS                1    E-CIG RETAILER
# 16888    TX  78645  4781.0  TRAVIS              190  CIG/TOB RETAILER
# 18388    TX  78645  4528.0  TRAVIS              259  CIG/TOB RETAILER
# 19058    TX  78645  8712.0  TRAVIS                1  CIG/TOB RETAILER
# 28305    TX  78645  5283.0  TRAVIS                1  CIG/TOB RETAILER
# 28306    TX  78645  5283.0  TRAVIS                1    E-CIG RETAILER
# 31949    TX  78645  5161.0  TRAVIS                1  CIG/TOB RETAILER
# 31950    TX  78645  5161.0  TRAVIS                1    E-CIG RETAILER
# 32963    TX  78645  4409.0  TRAVIS                1  CIG/TOB RETAILER
# 32964    TX  78645  4409.0  TRAVIS                1    E-CIG RETAILER
# 39296    TX  78645  4782.0  TRAVIS                1  CIG/TOB RETAILER
# 48915    TX  78645     NaN  TRAVIS                1  CIG/TOB RETAILER
# 48916    TX  78645     NaN  TRAVIS                1    E-CIG RETAILER
# 48917    TX  78645     NaN  TRAVIS                1  CIG/TOB RETAILER
# 48918    TX  78645     NaN  TRAVIS                1    E-CIG RETAILER
# 51365    TX  78645  4788.0  TRAVIS                1  CIG/TOB RETAILER
# 66527    TX  78645  7201.0  TRAVIS                1    E-CIG RETAILER
#
#        Permit Number Permit Status Permit Begin Date Permit End Date
# 5886      13001385.0        ACTIVE        01/15/2013             NaN
# 10521      8002772.0        ACTIVE        07/01/2008             NaN
# 10590     22006383.0        ACTIVE        05/01/2022             NaN
# 12503     99001645.0        ACTIVE        05/01/1999             NaN
# 12504     21007132.0        ACTIVE        01/01/2022             NaN
# 16888     12000941.0        ACTIVE        01/18/2012             NaN
# 18388     23000045.0        ACTIVE        04/01/2023             NaN
# 19058            NaN      INACTIVE        04/01/2007      05/31/2022
# 28305      9004261.0        ACTIVE        11/10/2009             NaN
# 28306     21010761.0        ACTIVE        01/01/2022             NaN
# 31949     17001242.0        ACTIVE        06/15/2017             NaN
# 31950     22007492.0        ACTIVE        06/01/2022             NaN
# 32963     13001450.0        ACTIVE        03/01/2013             NaN
# 32964     21010785.0        ACTIVE        01/01/2022             NaN
# 39296     15003443.0        ACTIVE        11/01/2015             NaN
# 48915     21000537.0        ACTIVE        02/06/2021             NaN
# 48916     21007883.0        ACTIVE        01/01/2022             NaN
# 48917     20062737.0        ACTIVE        06/18/2020             NaN
# 48918     21004882.0        ACTIVE        01/01/2022             NaN
# 51365     19001504.0      INACTIVE        08/01/2019             NaN
# 66527            NaN      INACTIVE        08/31/2022             NaN

# %% [markdown]
# In the absence of any row with corresponding properties with that of the row with missing location name (index 66527) by which the loaction can be deduced, the row will be dropped

# %%
# dropping location row with null value

df.dropna(subset=["Location Name"], axis = 0, inplace = True)

# %%
# confirming row drop

df.shape
# Out:
# (73600, 15)

# %%
# Changing "Permit Begin Date" and "Permit End Date" column data type to datetime64

df[["Permit Begin Date", "Permit End Date"]] = df[["Permit Begin Date", "Permit End Date"]].astype("datetime64[ns]")

# %%
# checking for confirmation

df.dtypes
# Out:
# Taxpayer Id                   int64
# Taxpayer Name                object
# Location Name                object
# Address                      object
# City                         object
# State                        object
# Zip                           int64
# Zip+4                       float64
# County                       object
# Location Number               int64
# Permit Type                  object
# Permit Number               float64
# Permit Status                object
# Permit Begin Date    datetime64[ns]
# Permit End Date      datetime64[ns]
# dtype: object

# %%
df.head(10)
# Out:
#    Taxpayer Id            Taxpayer Name              Location Name  \
# 0  10106415143     SHELLIE CURTIS, INC.  MIGALITOS SUPERMERCADO #3
# 1  12011638892    BAYWAY BUSINESS, INC.              R D FOOD MART
# 2  10106415143     SHELLIE CURTIS, INC.  MIGALITOS SUPERMERCADO #4
# 3  12010833395                  JTP LLC                   PORTER'S
# 4  10106576951             SOFIAN, INC.              SDS FOOD MART
# 5  12036882780   AUSTIN PETROLEUM, INC.                  BREAKTIME
# 6  10106931867       STARCO OIL CO INC.               TOBACCO STOP
# 7  10106931867       STARCO OIL CO INC.               TOBACCO STOP
# 8  10105547839  S S S ENTERPRISES, INC.             ON THE GO MART
# 9  10106136012    YAM ENTERPRISES, INC.             STOP N SHOP #2
#
#                     Address        City State    Zip   Zip+4     County  \
# 0    3939 S POLK ST STE 323      DALLAS    TX  75224  4423.0     DALLAS
# 1            6114 DECKER DR     BAYTOWN    TX  77520  1444.0     HARRIS
# 2  333 S SAINT AUGUSTINE DR      DALLAS    TX  75217  7488.0     DALLAS
# 3            703 E FRONT ST     MIDLAND    TX  79701  4834.0    MIDLAND
# 4  4924 WHITE SETTLEMENT RD  FORT WORTH    TX  76114  3919.0    TARRANT
# 5            3502 MANGUM RD     HOUSTON    TX  77092  7418.0     HARRIS
# 6       117 INTERSTATE 45 S  HUNTSVILLE    TX  77340  4243.0     WALKER
# 7       117 INTERSTATE 45 S  HUNTSVILLE    TX  77340  4243.0     WALKER
# 8            8901 HOWARD DR     HOUSTON    TX  77017  5430.0     HARRIS
# 9             1301 AVENUE I   ROSENBERG    TX  77471  3205.0  FORT BEND
#
#    Location Number       Permit Type  Permit Number Permit Status  \
# 0                5  CIG/TOB RETAILER     22011140.0        ACTIVE
# 1                1    E-CIG RETAILER     22000106.0        ACTIVE
# 2                6  CIG/TOB RETAILER     22011243.0        ACTIVE
# 3                9  CIG/TOB RETAILER     19000685.0        ACTIVE
# 4                1  CIG/TOB RETAILER      3004834.0        ACTIVE
# 5                5    E-CIG RETAILER     21010591.0      INACTIVE
# 6                4  CIG/TOB RETAILER     12003229.0        ACTIVE
# 7                4    E-CIG RETAILER     21013363.0        ACTIVE
# 8                2    E-CIG RETAILER     22002640.0        ACTIVE
# 9                2  CIG/TOB RETAILER      2003938.0        ACTIVE
#
#   Permit Begin Date Permit End Date
# 0        2022-08-26             NaT
# 1        2022-01-01             NaT
# 2        2022-08-26             NaT
# 3        2019-03-18             NaT
# 4        2004-01-01             NaT
# 5        2022-01-01      2022-11-02
# 6        2012-05-21             NaT
# 7        2022-01-01             NaT
# 8        2022-02-05             NaT
# 9        2002-07-01             NaT

# %%
#  Checking for retail purchase per state

df["State"].value_counts()
# Out:
# TX    73563
# CA        8
# FL        5
# NY        4
# NV        2
# VA        2
# PA        2
# NC        2
# CO        2
# NJ        1
# MO        1
# MD        1
# SC        1
# RI        1
# AZ        1
# KY        1
# MN        1
# WA        1
# DE        1
# Name: State, dtype: int64

# %%
# Filtering dataset into Texas as the state with the highest retail purchase by great margin

df = df[df["State"]== "TX"]

# %%
# Changing notebook display settings to enable view of all rows

pd.set_option("display.max_rows", None)

# %%
# List of cities with retail purchase in Texas

df["City"].value_counts()
# Out:
# HOUSTON    284
# Name: City, dtype: int64

# %%
# Filtering dataset into retail purchase from HOUSTON

df = df[df["City"]== "HOUSTON"]
df.head(5)
# Out:
#     Taxpayer Id               Taxpayer Name          Location Name  \
# 5   12036882780      AUSTIN PETROLEUM, INC.              BREAKTIME
# 8   10105547839     S S S ENTERPRISES, INC.         ON THE GO MART
# 14  12624594912  TEXAS PETROLEUM GROUP, LLC          TIMEWISE #839
# 61  10438331828                 ANRUS, INC.  MI TIENDA MEAT MARKET
# 62  10305251034       KUIFS PETROLEUM, L.P.                 KS #32
#
#                             Address     City State    Zip   Zip+4  County  \
# 5                    3502 MANGUM RD  HOUSTON    TX  77092  7418.0  HARRIS
# 8                    8901 HOWARD DR  HOUSTON    TX  77017  5430.0  HARRIS
# 14                    8155 KATY FWY  HOUSTON    TX  77024  1909.0  HARRIS
# 61              10211 CLUB CREEK DR  HOUSTON    TX  77036  7105.0  HARRIS
# 62  8055 N SAM HOUSTON PKWY W STE A  HOUSTON    TX  77064  3456.0  HARRIS
#
#     Location Number       Permit Type  Permit Number Permit Status  \
# 5                 5    E-CIG RETAILER     21010591.0      INACTIVE
# 8                 2    E-CIG RETAILER     22002640.0        ACTIVE
# 14              195  CIG/TOB RETAILER     21012908.0      INACTIVE
# 61                1  CIG/TOB RETAILER      6001455.0        ACTIVE
# 62               34    E-CIG RETAILER     21010157.0        ACTIVE
#
#    Permit Begin Date Permit End Date
# 5         2022-01-01      2022-11-02
# 8         2022-02-05             NaT
# 14        2021-12-30      2022-05-23
# 61        2006-03-01             NaT
# 62        2022-01-01             NaT

# %%
# Checking for County with retail purchase

df["County"].value_counts()
# Out:
# HARRIS        10186
# FORT BEND        84
# MONTGOMERY        3
# Name: County, dtype: int64

# %%
# Filtering dataset into retail purchase from HARRIS county as the county with the most retail purchase

df = df[df["County"]== "HARRIS"]
df.head(5)
# Out:
#       Taxpayer Id                      Taxpayer Name  \
# 897   12017692026    ENLIGHT INVESTMENTS CORPORATION
# 898   12017692026    ENLIGHT INVESTMENTS CORPORATION
# 1465  12048616754  SUPERMERCADO TELOLOAPAN # 8, INC.
# 1617  12055498534                           ZRN, LLC
# 1618  12055498534                           ZRN, LLC
#
#                   Location Name                Address     City State    Zip  \
# 897           SUPER K FOOD MART  4302 HICKORY DOWNS DR  HOUSTON    TX  77084
# 898           SUPER K FOOD MART  4302 HICKORY DOWNS DR  HOUSTON    TX  77084
# 1465  TELOLOAPAN MEAT MARKET #8       5420 HIGHWAY 6 N  HOUSTON    TX  77084
# 1617       GREENHOUSE FOOD MART     3207 GREENHOUSE RD  HOUSTON    TX  77084
# 1618       GREENHOUSE FOOD MART     3207 GREENHOUSE RD  HOUSTON    TX  77084
#
#        Zip+4  County  Location Number       Permit Type  Permit Number  \
# 897   3516.0  HARRIS                1  CIG/TOB RETAILER      4005738.0
# 898   3516.0  HARRIS                1    E-CIG RETAILER     21008786.0
# 1465  1826.0  HARRIS                2  CIG/TOB RETAILER      8000323.0
# 1617  4419.0  HARRIS               49  CIG/TOB RETAILER     21009719.0
# 1618  4419.0  HARRIS               49    E-CIG RETAILER     22004360.0
#
#      Permit Status Permit Begin Date Permit End Date
# 897         ACTIVE        2004-11-01             NaT
# 898         ACTIVE        2022-01-01             NaT
# 1465        ACTIVE        2007-11-01             NaT
# 1617        ACTIVE        2021-12-15             NaT
# 1618        ACTIVE        2022-02-16             NaT

# %%
# Checking for zip with the most retail purchase

df["Zip"].value_counts()
# Out:
# 77084    284
# 77036    248
# 77015    222
# 77070    215
# 77077    208
#         ...
# 77339      2
# 77546      2
# 77598      1
# 77201      1
# 77449      1
# Name: Zip, Length: 104, dtype: int64

# %%
# Filtering dataset into zip address with the higest retail purchase

df = df[df["Zip"]== 77084]
df.head(10)
# Out:
#       Taxpayer Id                      Taxpayer Name  \
# 897   12017692026    ENLIGHT INVESTMENTS CORPORATION
# 898   12017692026    ENLIGHT INVESTMENTS CORPORATION
# 1465  12048616754  SUPERMERCADO TELOLOAPAN # 8, INC.
# 1617  12055498534                           ZRN, LLC
# 1618  12055498534                           ZRN, LLC
# 1641  12056256899          VALLIANI ENTERPRISES INC.
# 2137  12603039020                   RUBEN FOODS, INC
# 2181  12604310693               ALCONOMY GROUP, INC.
# 2519  12624559725                 MALIK & SONS, INC.
# 2693  12624594912         TEXAS PETROLEUM GROUP, LLC
#
#                             Location Name                       Address  \
# 897                     SUPER K FOOD MART         4302 HICKORY DOWNS DR
# 898                     SUPER K FOOD MART         4302 HICKORY DOWNS DR
# 1465            TELOLOAPAN MEAT MARKET #8              5420 HIGHWAY 6 N
# 1617                 GREENHOUSE FOOD MART            3207 GREENHOUSE RD
# 1618                 GREENHOUSE FOOD MART            3207 GREENHOUSE RD
# 1641                     GREENHOUSE CITGO            3207 GREENHOUSE RD
# 2137                  GARCIA'S FOOD STORE  17550 W LITTLE YORK RD STE 1
# 2181                          ALCO LIQUOR  2919 BARKER CYPRESS RD STE K
# 2519  ONE STOP - DEERFIELD / CHAPIN TIRES                 18323 CLAY RD
# 2693                        TIMEWISE #829              4255 HIGHWAY 6 N
#
#          City State    Zip   Zip+4  County  Location Number       Permit Type  \
# 897   HOUSTON    TX  77084  3516.0  HARRIS                1  CIG/TOB RETAILER
# 898   HOUSTON    TX  77084  3516.0  HARRIS                1    E-CIG RETAILER
# 1465  HOUSTON    TX  77084  1826.0  HARRIS                2  CIG/TOB RETAILER
# 1617  HOUSTON    TX  77084  4419.0  HARRIS               49  CIG/TOB RETAILER
# 1618  HOUSTON    TX  77084  4419.0  HARRIS               49    E-CIG RETAILER
# 1641  HOUSTON    TX  77084  4419.0  HARRIS                1  CIG/TOB RETAILER
# 2137  HOUSTON    TX  77084  6321.0  HARRIS                1  CIG/TOB RETAILER
# 2181  HOUSTON    TX  77084  6869.0  HARRIS                2  CIG/TOB RETAILER
# 2519  HOUSTON    TX  77084  3915.0  HARRIS                1  CIG/TOB RETAILER
# 2693  HOUSTON    TX  77084  5411.0  HARRIS              185  CIG/TOB RETAILER
#
#       Permit Number Permit Status Permit Begin Date Permit End Date
# 897       4005738.0        ACTIVE        2004-11-01             NaT
# 898      21008786.0        ACTIVE        2022-01-01             NaT
# 1465      8000323.0        ACTIVE        2007-11-01             NaT
# 1617     21009719.0        ACTIVE        2021-12-15             NaT
# 1618     22004360.0        ACTIVE        2022-02-16             NaT
# 1641      6005978.0      INACTIVE        2006-11-10      2022-01-31
# 2137      7002747.0        ACTIVE        2007-07-15             NaT
# 2181     13002823.0        ACTIVE        2013-05-01             NaT
# 2519      8002774.0      INACTIVE        2008-07-01      2021-05-15
# 2693     21012903.0      INACTIVE        2021-12-30      2022-05-23

# %%
# Checking for number of unique retailers per address

Grouped_Zip_and_Address = df.groupby(["Address"])["Taxpayer Id"].nunique()
Grouped_Zip_and_Address.head(10)
# Out:
# Address
# 1206 BARKER CYPRESS RD             1
# 1219 HIGHWAY 6 N                   2
# 1430 BARKER CYPRESS RD             1
# 14838 PARK ROW DR STE D            1
# 1520 BARKER CYPRESS RD             2
# 15410 W LITTLE YORK RD             1
# 15410 W LITTLE YORK RD STE A       1
# 1550 FRY RD                        1
# 15852 YORKTOWN CROSSING PKWY       1
# 16212 LOCH KATRINE LN STE AANDB    1
# Name: Taxpayer Id, dtype: int64

# %%
# Checking number of retail purchase per address

df["Address"].value_counts()
# Out:
# 1893 BARKER CYPRESS RD             6
# 4521 HIGHWAY 6 N STE F             5
# 18311 CLAY RD STE B2               5
# 4255 HIGHWAY 6 N                   5
# 18324 CLAY RD                      5
# 2919 BARKER CYPRESS RD STE E       4
# 17102 W LITTLE YORK RD             4
# 6102 HIGHWAY 6 N                   4
# 6495 BARKER CYPRESS RD STE A       4
# 5920 HIGHWAY 6 N STE 1002          4
# 1219 HIGHWAY 6 N                   4
# 4351 HIGHWAY 6 N                   4
# 1635 BARKER CYPRESS RD             3
# 4820 HIGHWAY 6 N                   3
# 18323 CLAY RD                      3
# 6172 HIGHWAY 6 N                   3
# 17111 KIETH HARROW BLVD STE A      3
# 5210 BARKER CYPRESS RD             3
# 16503 CLAY RD STE A                3
# 3207 GREENHOUSE RD                 3
# 17930 W LITTLE YORK RD             3
# 2112 FRY RD STE B                  3
# 5418 BARKER CYPRESS RD             3
# 4011 HIGHWAY 6 N                   3
# 5803 BARKER CYPRESS RD             3
# 17904 W LITTLE YORK RD STE E       3
# 17702 KIETH HARROW BLVD            3
# 1520 BARKER CYPRESS RD             3
# 19002 SAUMS RD                     3
# 16955 W LITTLE YORK RD             2
# 4981 HIGHWAY 6 N                   2
# 3207 GREENHOUSE RD STE A           2
# 1430 BARKER CYPRESS RD             2
# 5569 HIGHWAY 6 N                   2
# 17126 PINE FOREST LN               2
# 4826 HIGHWAY 6 N STE CC            2
# 16630 CLAY RD                      2
# 4522 HIGHWAY 6 N                   2
# 2230 FRY RD                        2
# 6951 BARKER CYPRESS RD             2
# 2925 BARKER CYPRESS RD             2
# 18691 CLAY RD                      2
# 15410 W LITTLE YORK RD             2
# 14838 PARK ROW DR STE D            2
# 2850 FRY RD                        2
# 2424 GREENHOUSE RD STE 110         2
# 1866 BARKER CYPRESS RD             2
# 4240 HIGHWAY 6 N STE D             2
# 6285 BARKER CYPRESS RD             2
# 2002 FRY RD STE 114                2
# 5418 BARKER CYPRESS RD STE C       2
# 17830 CLAY RD                      2
# 3010 BARKER CYPRESS RD STE B       2
# 17441 W LITTLE YORK RD             2
# 16640 KIETH HARROW BLVD            2
# 16500 CLAY RD # A                  2
# 5502 HIGHWAY 6 N                   2
# 3014 BARKER CYPRESS RD UNIT 110    2
# 18006 PARK ROW STE 150             2
# 6914 LAKEVIEW HAVEN DR             2
# 6925 LAKEVIEW HAVEN DR             2
# 2404 GREENHOUSE RD                 2
# 3603 GREENHOUSE RD STE A           2
# 4603 HIGHWAY 6 N                   2
# 5211 BARKER CYPRESS RD STE 105     2
# 3014 BARKER CYPRESS RD STE 110     2
# 6211 BARKER CYPRESS RD STE 101     2
# 1855 BARKER CYPRESS RD STE 120     2
# 17602 W LITTLE YORK RD STE 5       2
# 3603 GREENHOUSE RD STE D           2
# 16286 LOCH KATRINE LN              2
# 5930 HIGHWAY 6 N STE A6            2
# 4025 HIGHWAY 6 N STE 100           2
# 3003 BARKER CYPRESS RD             2
# 1950 FRY RD                        2
# 2424 GREENHOUSE RD STE 130         2
# 1206 BARKER CYPRESS RD             2
# 17105 CLAY RD STE A                2
# 1718 FRY RD                        2
# 5432 HIGHWAY 6 N STE 307           2
# 5515 HIGHWAY 6 N                   2
# 15410 W LITTLE YORK RD STE A       2
# 5211 BARKER CYPRESS RD STE 110     2
# 4909 GREENHOUSE RD                 2
# 6309 BARKER CYPRESS RD STE A       2
# 4814 HIGHWAY 6 N                   2
# 5734 BARKER CYPRESS RD             2
# 4302 HICKORY DOWNS DR              2
# 2450 FRY RD                        2
# 16215 CLAY RD STE 203              2
# 3700 BARKER CYPRESS RD STE 700     2
# 4974 HIGHWAY 6 N                   2
# 15852 YORKTOWN CROSSING PKWY       2
# 2002 FRY RD STE 117                2
# 5820 HIGHWAY 6 N                   1
# 18003 CLAY RD                      1
# 3716 GREENHOUSE RD                 1
# 4505 HIGHWAY 6 N STE 1500          1
# 3006 DEEDS RD                      1
# 2002 FRY RD STE 105-106            1
# 3700 BARKER CYPRESS RD # 700       1
# 3722 BARKER CYPRESS RD             1
# 16503 CLAY RD                      1
# 2002 FRY RD STE 115B               1
# 5432 HIGHWAY 6 N                   1
# 17550 W LITTLE YORK RD STE 1       1
# 3880 GREENHOUSE RD STE 427         1
# 4830 HIGHWAY 6 N STE 8             1
# 4026 TREY DR                       1
# 6172 BARKER CYPRESS RD STE 500     1
# 1710 N FRY RD                      1
# 6333 BARKER CYPRESS RD             1
# 4007 BARKER CYPRESS RD             1
# 4810 HIGHWAY 6 N                   1
# 6011 ADDICKS SATSUMA RD            1
# 3231 APPLE DALE DR                 1
# 2923 BARKER CYPRESS RD STE B       1
# 2919 BARKER CYPRESS RD STE K       1
# 5222 BARKER CYPRESS RD STE 170     1
# 5222 BARKER CYPRESS RD STE 120     1
# 18322 CLAY RD                      1
# 4330 HIGHWAY 6 N                   1
# 2925 BARKER CYPRESS RD STE A       1
# 1855 BARKER CYPRESS RD STE 160     1
# 1550 FRY RD                        1
# 5420 HIGHWAY 6 N                   1
# 1940 FRY RD                        1
# 17904 W LITTLE YORK RD             1
# 3010 BARKER CYPRESS RD             1
# 16212 LOCH KATRINE LN STE AANDB    1
# 6280 BARKER CYPRESS RD             1
# 1856 BARKER CYPRESS RD             1
# 3700 BARKER CYPRESS RD STE 100     1
# 16618 CLAY RD STE 450              1
# 4955 HIGHWAY 6 N                   1
# 17802 W LITTLE YORK RD STE 200     1
# 4995 HIGHWAY 6 N                   1
# 4466 HIGHWAY 6 N                   1
# 1880 BARKER CYPRESS RD             1
# 16212 LOCH KATRINE LN STE AB       1
# 5410 HIGHWAY 6 N STE B             1
# 4707 HIGHWAY 6 N                   1
# 19419 CLEVERA WALK LN              1
# Name: Address, dtype: int64

# %%
# Checking address with the most retail purchase

Address_most_retail_purchase = (df['Address'].value_counts()[df['Address'].value_counts()> 3])

Address_most_retail_purchase
# Out:
# 1893 BARKER CYPRESS RD          6
# 4521 HIGHWAY 6 N STE F          5
# 18311 CLAY RD STE B2            5
# 4255 HIGHWAY 6 N                5
# 18324 CLAY RD                   5
# 2919 BARKER CYPRESS RD STE E    4
# 17102 W LITTLE YORK RD          4
# 6102 HIGHWAY 6 N                4
# 6495 BARKER CYPRESS RD STE A    4
# 5920 HIGHWAY 6 N STE 1002       4
# 1219 HIGHWAY 6 N                4
# 4351 HIGHWAY 6 N                4
# Name: Address, dtype: int64
